# %%
print("Hello World")
# Out:
# Hello World

# %%
data = [
  [
    "Click new tab",
    "Go to AWS Login Page",
    "Enter username",
    "Enter password",
    "Click Login Button",
    "Go to Services",
    "Select EC2",
    "Click Launch Instance",
    "Select AMI",
    "Choose Instance Type",
    "Click Review and Launch",
    "Click Launch"
  ],
  [
    "Open AWS Management Console",
    "Enter username",
    "Enter password",
    "Click Login Button",
    "Navigate to Services",
    "Select IAM",
    "Click on Users",
    "Choose Add User",
    "Enter User Details",
    "Attach Policies",
    "Click Create User"
  ],
  [
    "Click new tab",
    "Go to AWS Login Page",
    "Enter username",
    "Enter password",
    "Click Login Button",
    "Select Services",
    "Navigate to RDS",
    "Click Create Database",
    "Choose Database Engine",
    "Configure Settings",
    "Click Create"
  ],
  [
    "Open AWS Console",
    "Enter Login Credentials",
    "Select Services",
    "Choose Lambda",
    "Click Create Function",
    "Enter Function Name",
    "Choose Runtime",
    "Click Create",
    "Upload Code"
  ],
  [
    "Go to AWS Console",
    "Enter username",
    "Enter password",
    "Select Services",
    "Go to CloudFormation",
    "Click Create Stack",
    "Upload Template File",
    "Click Next",
    "Configure Stack Settings",
    "Click Create Stack"
  ],
  [
    "Open AWS Login Page",
    "Enter username",
    "Enter password",
    "Click Login Button",
    "Navigate to S3",
    "Click Create Bucket",
    "Enter Bucket Name",
    "Choose Region",
    "Click Create"
  ],
  [
    "Open AWS Console",
    "Enter username",
    "Enter password",
    "Go to Services",
    "Select CloudWatch",
    "Click Create Alarm",
    "Choose Metric",
    "Set Conditions",
    "Click Next",
    "Configure Notifications",
    "Click Create Alarm"
  ],
  [
    "Go to AWS Console",
    "Enter Login Information",
    "Select Services",
    "Navigate to VPC",
    "Click Create VPC",
    "Enter VPC Details",
    "Click Create VPC",
    "Go to Subnets",
    "Click Create Subnet",
    "Enter Subnet Details",
    "Click Create Subnet"
  ],
  [
    "Click new tab",
    "Go to AWS Login Page",
    "Enter username",
    "Enter password",
    "Click Login Button",
    "Select Services",
    "Navigate to Elastic Beanstalk",
    "Click Create New Application",
    "Enter Application Name",
    "Choose Platform",
    "Click Create"
  ],
  [
    "Open AWS Console",
    "Enter username",
    "Enter password",
    "Click Login Button",
    "Select Services",
    "Go to Route 53",
    "Click Create Hosted Zone",
    "Enter Domain Name",
    "Configure Settings",
    "Click Create"
  ], 
    [
  [
    "Open AWS Console",
    "Enter username",
    "Enter password",
    "Click Login Button",
    "Navigate to Services",
    "Select S3",
    "Choose a Bucket",
    "Click Permissions Tab",
    "Edit Bucket Policy",
    "Save Changes"
  ],
  [
    "Go to AWS Login Page",
    "Enter username",
    "Enter password",
    "Click Login Button",
    "Navigate to Services",
    "Select DynamoDB",
    "Click Create Table",
    "Enter Table Name",
    "Specify Primary Key",
    "Click Create Table"
  ],
  [
    "Open AWS Console",
    "Enter Login Credentials",
    "Select Services",
    "Go to SNS",
    "Click Create Topic",
    "Enter Topic Name",
    "Choose Type",
    "Click Create Topic",
    "Copy ARN"
  ],
  [
    "Click new tab",
    "Go to AWS Login Page",
    "Enter username",
    "Enter password",
    "Click Login Button",
    "Select Services",
    "Navigate to Elastic Load Balancing",
    "Click Create Load Balancer",
    "Select Load Balancer Type",
    "Configure Settings",
    "Click Create"
  ],
  [
    "Open AWS Console",
    "Enter Login Information",
    "Navigate to Services",
    "Select ECS",
    "Click Create Cluster",
    "Select Cluster Template",
    "Configure Cluster Settings",
    "Click Create Cluster"
  ],
  [
    "Go to AWS Management Console",
    "Enter username",
    "Enter password",
    "Click Login Button",
    "Select Services",
    "Choose CodePipeline",
    "Click Create Pipeline",
    "Enter Pipeline Name",
    "Configure Stages",
    "Click Create Pipeline"
  ],
  [
    "Open AWS Console",
    "Enter username",
    "Enter password",
    "Click Login Button",
    "Navigate to Services",
    "Select AWS Backup",
    "Click Create Backup Plan",
    "Enter Plan Name",
    "Define Backup Rules",
    "Click Create Plan"
  ],
  [
    "Open AWS Console",
    "Enter Login Information",
    "Select Services",
    "Choose Systems Manager",
    "Click Automation",
    "Create New Automation",
    "Select Document Type",
    "Configure Execution Parameters",
    "Click Execute"
  ],
  [
    "Go to AWS Login Page",
    "Enter username",
    "Enter password",
    "Click Login Button",
    "Navigate to Services",
    "Select ElasticSearch",
    "Click Create Domain",
    "Enter Domain Name",
    "Configure Settings",
    "Click Create"
  ],
  [
    "Open AWS Console",
    "Enter Login Credentials",
    "Select Services",
    "Navigate to Step Functions",
    "Click Create State Machine",
    "Enter State Machine Name",
    "Define State Machine Workflow",
    "Click Create"
  ]
]
]

# %%
#get data
#put into embedding space with next node as a linked list element
#collect this massive graph
#

#at inference time, find nearest neighbor and return the possible next nodes based on traffic
#use a languamodel to select the next ndoe based on this one's specific context
# repeat until you have a full path

# %%
# !pip install openai
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: openai in /Users/sasankaduri/Library/Python/3.9/lib/python/site-packages (1.44.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/sasankaduri/Library/Python/3.9/lib/python/site-packages (from openai) (4.4.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/sasankaduri/Library/Python/3.9/lib/python/site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/sasankaduri/Library/Python/3.9/lib/python/site-packages (from openai) (0.27.2)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/sasankaduri/Library/Python/3.9/lib/python/site-packages (from openai) (0.5.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/sasankaduri/Library/Python/3.9/lib/python/site-packages (from openai) (2.9.1)
# Requirement already satisfied: sniffio in /Users/sasankaduri/Library/Python/3.9/lib/python/site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Users/sasankaduri/Library/Python/3.9/lib/python/site-packages (from openai) (4.66.5)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /Users/sasankaduri/Library/Python/3.9/lib/python/site-packages (from openai) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /Users/sasankaduri/Library/Python/3.9/lib/python/site-packages (from anyio<5,>=3.5.0->openai) (3.8)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/sasankaduri/Library/Python/3.9/lib/python/site-packages (from anyio<5,>=3.5.0->openai) (1.2.2)
# Requirement already satisfied: certifi in /Users/sasankaduri/Library/Python/3.9/lib/python/site-packages (from httpx<1,>=0.23.0->openai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /Users/sasankaduri/Library/Python/3.9/lib/python/site-packages (from httpx<1,>=0.23.0->openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/sasankaduri/Library/Python/3.9/lib/python/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/sasankaduri/Library/Python/3.9/lib/python/site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.3 in /Users/sasankaduri/Library/Python/3.9/lib/python/site-packages (from pydantic<3,>=1.9.0->openai) (2.23.3)
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip

# %%
# !pip install sentence-transformers
# !pip install numpy
# !pip install scipy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting sentence-transformers
#   Downloading sentence_transformers-3.3.0-py3-none-any.whl.metadata (10 kB)
# Collecting transformers<5.0.0,>=4.41.0 (from sentence-transformers)
#   Downloading transformers-4.46.2-py3-none-any.whl.metadata (44 kB)
# Requirement already satisfied: tqdm in /Users/sasankaduri/Library/Python/3.9/lib/python/site-packages (from sentence-transformers) (4.66.5)
# Requirement already satisfied: torch>=1.11.0 in /Users/sasankaduri/Library/Python/3.9/lib/python/site-packages (from sentence-transformers) (2.4.1)
# Collecting scikit-learn (from sentence-transformers)
#   Downloading scikit_learn-1.5.2-cp39-cp39-macosx_12_0_arm64.whl.metadata (13 kB)
# Collecting scipy (from sentence-transformers)
#   Downloading scipy-1.13.1-cp39-cp39-macosx_12_0_arm64.whl.metadata (60 kB)
# Collecting huggingface-hub>=0.20.0 (from sentence-transformers)
#   Downloading huggingface_hub-0.26.2-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: Pillow in /Users/sasankaduri/Library/Python/3.9/lib/python/site-packages (from sentence-transformers) (10.4.0)
# Requirement already satisfied: filelock in /Users/sasankaduri/Library/Python/3.9/lib/python/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/sasankaduri/Library/Python/3.9/lib/python/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2024.9.0)
# Requirement already satisfied: packaging>=20.9 in /Users/sasankaduri/Library/Python/3.9/lib/python/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (24.1)
# Collecting pyyaml>=5.1 (from huggingface-hub>=0.20.0->sentence-transformers)
#   Using cached PyYAML-6.0.2-cp39-cp39-macosx_11_0_arm64.whl.metadata (2.1 kB)
# Collecting requests (from huggingface-hub>=0.20.0->sentence-transformers)
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/sasankaduri/Library/Python/3.9/lib/python/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (4.12.2)
# Requirement already satisfied: sympy in /Users/sasankaduri/Library/Python/3.9/lib/python/site-packages (from torch>=1.11.0->sentence-transformers) (1.13.2)
# Requirement already satisfied: networkx in /Users/sasankaduri/Library/Python/3.9/lib/python/site-packages (from torch>=1.11.0->sentence-transformers) (3.2.1)
# Requirement already satisfied: jinja2 in /Users/sasankaduri/Library/Python/3.9/lib/python/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.4)
# Requirement already satisfied: numpy>=1.17 in /Users/sasankaduri/Library/Python/3.9/lib/python/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2.0.2)
# Collecting regex!=2019.12.17 (from transformers<5.0.0,>=4.41.0->sentence-transformers)
#   Downloading regex-2024.11.6-cp39-cp39-macosx_11_0_arm64.whl.metadata (40 kB)
# Collecting safetensors>=0.4.1 (from transformers<5.0.0,>=4.41.0->sentence-transformers)
#   Using cached safetensors-0.4.5-cp39-cp39-macosx_11_0_arm64.whl.metadata (3.8 kB)
# Collecting tokenizers<0.21,>=0.20 (from transformers<5.0.0,>=4.41.0->sentence-transformers)
#   Downloading tokenizers-0.20.3-cp39-cp39-macosx_11_0_arm64.whl.metadata (6.7 kB)
# Collecting joblib>=1.2.0 (from scikit-learn->sentence-transformers)
#   Using cached joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn->sentence-transformers)
#   Using cached threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/sasankaduri/Library/Python/3.9/lib/python/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.5)
# Collecting charset-normalizer<4,>=2 (from requests->huggingface-hub>=0.20.0->sentence-transformers)
#   Using cached charset_normalizer-3.4.0-cp39-cp39-macosx_11_0_arm64.whl.metadata (34 kB)
# Requirement already satisfied: idna<4,>=2.5 in /Users/sasankaduri/Library/Python/3.9/lib/python/site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.8)
# Collecting urllib3<3,>=1.21.1 (from requests->huggingface-hub>=0.20.0->sentence-transformers)
#   Using cached urllib3-2.2.3-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/sasankaduri/Library/Python/3.9/lib/python/site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2024.8.30)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/sasankaduri/Library/Python/3.9/lib/python/site-packages (from sympy->torch>=1.11.0->sentence-transformers) (1.3.0)
# Downloading sentence_transformers-3.3.0-py3-none-any.whl (268 kB)
# Downloading huggingface_hub-0.26.2-py3-none-any.whl (447 kB)
# Downloading transformers-4.46.2-py3-none-any.whl (10.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 37.5 MB/s eta 0:00:00 0:00:01
# Downloading scikit_learn-1.5.2-cp39-cp39-macosx_12_0_arm64.whl (11.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.0/11.0 MB 36.1 MB/s eta 0:00:00 0:00:01
# Downloading scipy-1.13.1-cp39-cp39-macosx_12_0_arm64.whl (30.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.3/30.3 MB 35.4 MB/s eta 0:00:00a 0:00:01
# Using cached joblib-1.4.2-py3-none-any.whl (301 kB)
# Using cached PyYAML-6.0.2-cp39-cp39-macosx_11_0_arm64.whl (172 kB)
# Downloading regex-2024.11.6-cp39-cp39-macosx_11_0_arm64.whl (284 kB)
# Using cached safetensors-0.4.5-cp39-cp39-macosx_11_0_arm64.whl (383 kB)
# Using cached threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Downloading tokenizers-0.20.3-cp39-cp39-macosx_11_0_arm64.whl (2.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 44.0 MB/s eta 0:00:00
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Using cached charset_normalizer-3.4.0-cp39-cp39-macosx_11_0_arm64.whl (120 kB)
# Using cached urllib3-2.2.3-py3-none-any.whl (126 kB)
# Installing collected packages: urllib3, threadpoolctl, scipy, safetensors, regex, pyyaml, joblib, charset-normalizer, scikit-learn, requests, huggingface-hub, tokenizers, transformers, sentence-transformers
# Successfully installed charset-normalizer-3.4.0 huggingface-hub-0.26.2 joblib-1.4.2 pyyaml-6.0.2 regex-2024.11.6 requests-2.32.3 safetensors-0.4.5 scikit-learn-1.5.2 scipy-1.13.1 sentence-transformers-3.3.0 threadpoolctl-3.5.0 tokenizers-0.20.3 transformers-4.46.2 urllib3-2.2.3
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy in /Users/sasankaduri/Library/Python/3.9/lib/python/site-packages (2.0.2)
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scipy in /Users/sasankaduri/Library/Python/3.9/lib/python/site-packages (1.13.1)
# Requirement already satisfied: numpy<2.3,>=1.22.4 in /Users/sasankaduri/Library/Python/3.9/lib/python/site-packages (from scipy) (2.0.2)
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip

# %%
from typing import List, Dict, Optional
import numpy as np
from scipy.spatial.distance import cosine
from sentence_transformers import SentenceTransformer
from collections import Counter

# Initialize the SentenceTransformer model
embedding_model = SentenceTransformer('all-MiniLM-L6-v2')

def generate_embedding(text: str) -> List[float]:
    """
    Generates an embedding for the given text using a pre-trained model.
    """
    embedding = embedding_model.encode(text)
    return embedding.tolist()

def extract_nodes_and_edges(sequences: List[List[str]]) -> List[Dict[str, any]]:
    nodes = {}
    print("Extracting nodes and edges from sequences...")
    for seq in sequences:
        print(f"Processing sequence: {seq}")
        for i, step in enumerate(seq):
            if step not in nodes:
                nodes[step] = {
                    "node_id": f"node_{len(nodes) + 1}",
                    "content": step,
                    "next_nodes": set()
                }
                print(f"Created node: {nodes[step]['node_id']} with content: '{step}'")
            if i < len(seq) - 1:
                next_step = seq[i + 1]
                if next_step not in nodes:
                    nodes[next_step] = {
                        "node_id": f"node_{len(nodes) + 1}",
                        "content": next_step,
                        "next_nodes": set()
                    }
                    print(f"Created node: {nodes[next_step]['node_id']} with content: '{next_step}'")
                nodes[step]["next_nodes"].add(nodes[next_step]["node_id"])
                print(f"Added edge from '{nodes[step]['node_id']}' to '{nodes[next_step]['node_id']}'")
    # Convert next_nodes from set to list
    for node in nodes.values():
        node["next_nodes"] = list(node["next_nodes"])
    return list(nodes.values())

def create_embeddings_with_metadata(nodes: List[Dict[str, any]]) -> List[Dict[str, any]]:
    embedded_data = []
    print("\nGenerating embeddings for each node...")
    for item in nodes:
        node_id = item["node_id"]
        next_nodes = item["next_nodes"]
        content = item["content"]

        # Generate embedding for the node's content
        embedding = generate_embedding(content)

        # Store the embedding with metadata
        embedded_node = {
            "node_id": node_id,
            "embedding": embedding,
            "next_nodes": next_nodes,
            "content": content
        }
        embedded_data.append(embedded_node)
        print(f"Node ID: {node_id}")
        print(f"Content: '{content}'")
        print(f"Next Nodes: {next_nodes}\n")
    return embedded_data

def find_nearest_node(query_embedding: List[float], embedded_data: List[Dict[str, any]]) -> Dict[str, any]:
    distances = []
    for item in embedded_data:
        distance = cosine(query_embedding, item['embedding'])
        distances.append((distance, item))
    distances.sort(key=lambda x: x[0])
    nearest_node = distances[0][1]
    print(f"\nNearest node to the query is Node ID: {nearest_node['node_id']} with content: '{nearest_node['content']}'")
    return nearest_node

def get_k_nearest_neighbors(current_node: Dict[str, any], embedded_data: List[Dict[str, any]], k: int) -> List[Dict[str, any]]:
    current_embedding = current_node['embedding']
    distances = []
    for item in embedded_data:
        distance = cosine(current_embedding, item['embedding'])
        distances.append((distance, item))
    distances.sort(key=lambda x: x[0])
    k_neighbors = [item for _, item in distances[:k]]
    print(f"\nK={k} nearest neighbors to Node ID: {current_node['node_id']}")
    for neighbor in k_neighbors:
        print(f"- Node ID: {neighbor['node_id']} | Content: '{neighbor['content']}'")
    return k_neighbors

def select_most_popular_next_node(k_neighbors: List[Dict[str, any]], embedded_data: List[Dict[str, any]]) -> Optional[Dict[str, any]]:
    next_nodes_counts = Counter()
    next_nodes_dict = {}

    print("\nCollecting outbound next nodes from k nearest neighbors...")
    for neighbor in k_neighbors:
        for next_node_id in neighbor['next_nodes']:
            next_node = next((item for item in embedded_data if item['node_id'] == next_node_id), None)
            if next_node:
                next_nodes_counts[next_node_id] += 1
                next_nodes_dict[next_node_id] = next_node

    if not next_nodes_counts:
        print("No next nodes found from k nearest neighbors.")
        return None

    print("Next nodes and their frequencies:")
    for node_id, count in next_nodes_counts.items():
        node_content = next_nodes_dict[node_id]['content']
        print(f"- Node ID: {node_id} | Content: '{node_content}' | Count: {count}")

    # Select the most popular next node (or the first if tied)
    
    #use an llm completion call to gpt-4o to select the proper next step based on the current accumulated state
    most_common = next_nodes_counts.most_common()
    highest_count = most_common[0][1]
    candidates = [node_id for node_id, count in most_common if count == highest_count]

    # Select the first candidate
    selected_node_id = candidates[0]
    selected_node = next_nodes_dict[selected_node_id]
    print(f"Selected next node: Node ID: {selected_node_id} | Content: '{selected_node['content']}'")
    return selected_node

def generate_full_path(query_content: str, embedded_data: List[Dict[str, any]], k: int) -> List[str]:
    print(f"\nGenerating embedding for query: '{query_content}'")
    query_embedding = generate_embedding(query_content)

    # Find the node closest to the query
    current_node = find_nearest_node(query_embedding, embedded_data)
    path = [current_node['node_id']]
    visited = set(path)

    while True:
        # Get k nearest neighbors of the current node
        k_neighbors = get_k_nearest_neighbors(current_node, embedded_data, k)

        # Select the most popular next node
        next_node = select_most_popular_next_node(k_neighbors, embedded_data)

        if not next_node or next_node['node_id'] in visited:
            print(f"\nStopping path generation. Next node: '{next_node['node_id'] if next_node else None}' | Visited: {visited}")
            break  # No more nodes to visit or loop detected

        path.append(next_node['node_id'])
        visited.add(next_node['node_id'])
        current_node = next_node

    return path

def node_id_to_content(node_id: str, embedded_data: List[Dict[str, any]]) -> str:
    node = next((item for item in embedded_data if item['node_id'] == node_id), None)
    return node['content'] if node else ""

# Example usage
if __name__ == "__main__":
    # Your input data
    sequences = [
        [
            "Open AWS Console",
            "Enter username",
            "Enter password",
            "Click Login Button",
            "Navigate to Services",
            "Select AWS Backup",
            "Click Create Backup Plan",
            "Enter Plan Name",
            "Define Backup Rules",
            "Click Create Plan"
        ],
        [
            "Open AWS Console",
            "Enter Login Information",
            "Select Services",
            "Choose Systems Manager",
            "Click Automation",
            "Create New Automation",
            "Select Document Type",
            "Configure Execution Parameters",
            "Click Execute"
        ],
        [
            "Go to AWS Login Page",
            "Enter username",
            "Enter password",
            "Click Login Button",
            "Navigate to Services",
            "Select ElasticSearch",
            "Click Create Domain",
            "Enter Domain Name",
            "Configure Settings",
            "Click Create"
        ],
        [
            "Open AWS Console",
            "Enter username",
            "Enter password",
            "Click Login Button",
            "Navigate to Services",
            "Select S3",
            "Click Create Bucket",
            "Enter Bucket Name",
            "Configure Bucket Settings",
            "Click Create Bucket"
        ],
    ]

    # Extract nodes and edges
    nodes = extract_nodes_and_edges(sequences)

    # Generate embeddings with metadata
    embedded_data = create_embeddings_with_metadata(nodes)

    # Query input
    query_content = "Create AWS bucket"
    k = 3  # Number of nearest neighbors to consider

    # Generate full path based on the query
    path_node_ids = generate_full_path(query_content, embedded_data, k)

    # Convert node IDs back to content for readability
    path_contents = [node_id_to_content(node_id, embedded_data) for node_id in path_node_ids]

    print("\nGenerated Path:")
    for step in path_contents:
        print(f"- {step}")
# Out:
# Extracting nodes and edges from sequences...
# Processing sequence: ['Open AWS Console', 'Enter username', 'Enter password', 'Click Login Button', 'Navigate to Services', 'Select AWS Backup', 'Click Create Backup Plan', 'Enter Plan Name', 'Define Backup Rules', 'Click Create Plan']
# Created node: node_1 with content: 'Open AWS Console'
# Created node: node_2 with content: 'Enter username'
# Added edge from 'node_1' to 'node_2'
# Created node: node_3 with content: 'Enter password'
# Added edge from 'node_2' to 'node_3'
# Created node: node_4 with content: 'Click Login Button'
# Added edge from 'node_3' to 'node_4'
# Created node: node_5 with content: 'Navigate to Services'
# Added edge from 'node_4' to 'node_5'
# Created node: node_6 with content: 'Select AWS Backup'
# Added edge from 'node_5' to 'node_6'
# Created node: node_7 with content: 'Click Create Backup Plan'
# Added edge from 'node_6' to 'node_7'
# Created node: node_8 with content: 'Enter Plan Name'
# Added edge from 'node_7' to 'node_8'
# Created node: node_9 with content: 'Define Backup Rules'
# Added edge from 'node_8' to 'node_9'
# Created node: node_10 with content: 'Click Create Plan'
# Added edge from 'node_9' to 'node_10'
# Processing sequence: ['Open AWS Console', 'Enter Login Information', 'Select Services', 'Choose Systems Manager', 'Click Automation', 'Create New Automation', 'Select Document Type', 'Configure Execution Parameters', 'Click Execute']
# Created node: node_11 with content: 'Enter Login Information'
# Added edge from 'node_1' to 'node_11'
# Created node: node_12 with content: 'Select Services'
# Added edge from 'node_11' to 'node_12'
# Created node: node_13 with content: 'Choose Systems Manager'
# Added edge from 'node_12' to 'node_13'
# Created node: node_14 with content: 'Click Automation'
# Added edge from 'node_13' to 'node_14'
# Created node: node_15 with content: 'Create New Automation'
# Added edge from 'node_14' to 'node_15'
# Created node: node_16 with content: 'Select Document Type'
# Added edge from 'node_15' to 'node_16'
# Created node: node_17 with content: 'Configure Execution Parameters'
# Added edge from 'node_16' to 'node_17'
# Created node: node_18 with content: 'Click Execute'
# Added edge from 'node_17' to 'node_18'
# Processing sequence: ['Go to AWS Login Page', 'Enter username', 'Enter password', 'Click Login Button', 'Navigate to Services', 'Select ElasticSearch', 'Click Create Domain', 'Enter Domain Name', 'Configure Settings', 'Click Create']
# Created node: node_19 with content: 'Go to AWS Login Page'
# Added edge from 'node_19' to 'node_2'
# Added edge from 'node_2' to 'node_3'
# Added edge from 'node_3' to 'node_4'
# Added edge from 'node_4' to 'node_5'
# Created node: node_20 with content: 'Select ElasticSearch'
# Added edge from 'node_5' to 'node_20'
# Created node: node_21 with content: 'Click Create Domain'
# Added edge from 'node_20' to 'node_21'
# Created node: node_22 with content: 'Enter Domain Name'
# Added edge from 'node_21' to 'node_22'
# Created node: node_23 with content: 'Configure Settings'
# Added edge from 'node_22' to 'node_23'
# Created node: node_24 with content: 'Click Create'
# Added edge from 'node_23' to 'node_24'
# Processing sequence: ['Open AWS Console', 'Enter username', 'Enter password', 'Click Login Button', 'Navigate to Services', 'Select S3', 'Click Create Bucket', 'Enter Bucket Name', 'Configure Bucket Settings', 'Click Create Bucket']
# Added edge from 'node_1' to 'node_2'
# Added edge from 'node_2' to 'node_3'
# Added edge from 'node_3' to 'node_4'
# Added edge from 'node_4' to 'node_5'
# Created node: node_25 with content: 'Select S3'
# Added edge from 'node_5' to 'node_25'
# Created node: node_26 with content: 'Click Create Bucket'
# Added edge from 'node_25' to 'node_26'
# Created node: node_27 with content: 'Enter Bucket Name'
# Added edge from 'node_26' to 'node_27'
# Created node: node_28 with content: 'Configure Bucket Settings'
# Added edge from 'node_27' to 'node_28'
# Added edge from 'node_28' to 'node_26'
#
# Generating embeddings for each node...
# Node ID: node_1
# Content: 'Open AWS Console'
# Next Nodes: ['node_11', 'node_2']
#
# Node ID: node_2
# Content: 'Enter username'
# Next Nodes: ['node_3']
#
# Node ID: node_3
# Content: 'Enter password'
# Next Nodes: ['node_4']
#
# Node ID: node_4
# Content: 'Click Login Button'
# Next Nodes: ['node_5']
#
# Node ID: node_5
# Content: 'Navigate to Services'
# Next Nodes: ['node_25', 'node_6', 'node_20']
#
# Node ID: node_6
# Content: 'Select AWS Backup'
# Next Nodes: ['node_7']
#
# Node ID: node_7
# Content: 'Click Create Backup Plan'
# Next Nodes: ['node_8']
#
# Node ID: node_8
# Content: 'Enter Plan Name'
# Next Nodes: ['node_9']
#
# Node ID: node_9
# Content: 'Define Backup Rules'
# Next Nodes: ['node_10']
#
# Node ID: node_10
# Content: 'Click Create Plan'
# Next Nodes: []
#
# Node ID: node_11
# Content: 'Enter Login Information'
# Next Nodes: ['node_12']
#
# Node ID: node_12
# Content: 'Select Services'
# Next Nodes: ['node_13']
#
# Node ID: node_13
# Content: 'Choose Systems Manager'
# Next Nodes: ['node_14']
#
# Node ID: node_14
# Content: 'Click Automation'
# Next Nodes: ['node_15']
#
# Node ID: node_15
# Content: 'Create New Automation'
# Next Nodes: ['node_16']
#
# Node ID: node_16
# Content: 'Select Document Type'
# Next Nodes: ['node_17']
#
# Node ID: node_17
# Content: 'Configure Execution Parameters'
# Next Nodes: ['node_18']
#
# Node ID: node_18
# Content: 'Click Execute'
# Next Nodes: []
#
# Node ID: node_19
# Content: 'Go to AWS Login Page'
# Next Nodes: ['node_2']
#
# Node ID: node_20
# Content: 'Select ElasticSearch'
# Next Nodes: ['node_21']
#
# Node ID: node_21
# Content: 'Click Create Domain'
# Next Nodes: ['node_22']
#
# Node ID: node_22
# Content: 'Enter Domain Name'
# Next Nodes: ['node_23']
#
# Node ID: node_23
# Content: 'Configure Settings'
# Next Nodes: ['node_24']
#
# Node ID: node_24
# Content: 'Click Create'
# Next Nodes: []
#
# Node ID: node_25
# Content: 'Select S3'
# Next Nodes: ['node_26']
#
# Node ID: node_26
# Content: 'Click Create Bucket'
# Next Nodes: ['node_27']
#
# Node ID: node_27
# Content: 'Enter Bucket Name'
# Next Nodes: ['node_28']
#
# Node ID: node_28
# Content: 'Configure Bucket Settings'
# Next Nodes: ['node_26']
#
#
# Generating embedding for query: 'Create AWS bucket'
#
# Nearest node to the query is Node ID: node_26 with content: 'Click Create Bucket'
#
# K=3 nearest neighbors to Node ID: node_26
# - Node ID: node_26 | Content: 'Click Create Bucket'
# - Node ID: node_27 | Content: 'Enter Bucket Name'
# - Node ID: node_28 | Content: 'Configure Bucket Settings'
#
# Collecting outbound next nodes from k nearest neighbors...
# Next nodes and their frequencies:
# - Node ID: node_27 | Content: 'Enter Bucket Name' | Count: 1
# - Node ID: node_28 | Content: 'Configure Bucket Settings' | Count: 1
# - Node ID: node_26 | Content: 'Click Create Bucket' | Count: 1
# Selected next node: Node ID: node_27 | Content: 'Enter Bucket Name'
#
# K=3 nearest neighbors to Node ID: node_27
# - Node ID: node_27 | Content: 'Enter Bucket Name'
# - Node ID: node_26 | Content: 'Click Create Bucket'
# - Node ID: node_28 | Content: 'Configure Bucket Settings'
#
# Collecting outbound next nodes from k nearest neighbors...
# Next nodes and their frequencies:
# - Node ID: node_28 | Content: 'Configure Bucket Settings' | Count: 1
# - Node ID: node_27 | Content: 'Enter Bucket Name' | Count: 1
# - Node ID: node_26 | Content: 'Click Create Bucket' | Count: 1
# Selected next node: Node ID: node_28 | Content: 'Configure Bucket Settings'
#
# K=3 nearest neighbors to Node ID: node_28
# - Node ID: node_28 | Content: 'Configure Bucket Settings'
# - Node ID: node_26 | Content: 'Click Create Bucket'
# - Node ID: node_27 | Content: 'Enter Bucket Name'
#
# Collecting outbound next nodes from k nearest neighbors...
# Next nodes and their frequencies:
# - Node ID: node_26 | Content: 'Click Create Bucket' | Count: 1
# - Node ID: node_27 | Content: 'Enter Bucket Name' | Count: 1
# - Node ID: node_28 | Content: 'Configure Bucket Settings' | Count: 1
# Selected next node: Node ID: node_26 | Content: 'Click Create Bucket'
#
# Stopping path generation. Next node: 'node_26' | Visited: {'node_27', 'node_28', 'node_26'}
#
# Generated Path:
# - Click Create Bucket
# - Enter Bucket Name
# - Configure Bucket Settings

# %%
from typing import List, Dict, Optional
import numpy as np
from scipy.spatial.distance import cosine
from sentence_transformers import SentenceTransformer
from openai import OpenAI
import os

client = OpenAI(
    api_key="sk-F3asg0l0-p8GpwVnuEtY5HP5vEIGrNGczale_Vm8zRT3BlbkFJZiaVgM6NipUOe2qY10I_zLI9tse3ZYRTpaRVaCjsEA"  # Recommended way to access the API key
)

# Initialize the SentenceTransformer model
embedding_model = SentenceTransformer('all-MiniLM-L6-v2')

def generate_embedding(text: str) -> List[float]:
    """
    Generates an embedding for the given text using a pre-trained model.
    """
    embedding = embedding_model.encode(text)
    return embedding.tolist()

def extract_nodes_and_edges(sequences: List[List[str]]) -> List[Dict[str, any]]:
    nodes = {}
    print("Extracting nodes and edges from sequences...")
    for seq in sequences:
        print(f"Processing sequence: {seq}")
        for i, step in enumerate(seq):
            if step not in nodes:
                nodes[step] = {
                    "node_id": f"node_{len(nodes) + 1}",
                    "content": step,
                    "next_nodes": set()
                }
                print(f"Created node: {nodes[step]['node_id']} with content: '{step}'")
            if i < len(seq) - 1:
                next_step = seq[i + 1]
                if next_step not in nodes:
                    nodes[next_step] = {
                        "node_id": f"node_{len(nodes) + 1}",
                        "content": next_step,
                        "next_nodes": set()
                    }
                    print(f"Created node: {nodes[next_step]['node_id']} with content: '{next_step}'")
                nodes[step]["next_nodes"].add(nodes[next_step]["node_id"])
                print(f"Added edge from '{nodes[step]['node_id']}' to '{nodes[next_step]['node_id']}'")
    # Convert next_nodes from set to list
    for node in nodes.values():
        node["next_nodes"] = list(node["next_nodes"])
    return list(nodes.values())

def create_embeddings_with_metadata(nodes: List[Dict[str, any]]) -> List[Dict[str, any]]:
    embedded_data = []
    print("\nGenerating embeddings for each node...")
    for item in nodes:
        node_id = item["node_id"]
        next_nodes = item["next_nodes"]
        content = item["content"]

        # Generate embedding for the node's content
        embedding = generate_embedding(content)

        # Store the embedding with metadata
        embedded_node = {
            "node_id": node_id,
            "embedding": embedding,
            "next_nodes": next_nodes,
            "content": content
        }
        embedded_data.append(embedded_node)
        print(f"Node ID: {node_id}")
        print(f"Content: '{content}'")
        print(f"Next Nodes: {next_nodes}\n")
    return embedded_data

def find_nearest_node(query_embedding: List[float], embedded_data: List[Dict[str, any]]) -> Dict[str, any]:
    distances = []
    for item in embedded_data:
        distance = cosine(query_embedding, item['embedding'])
        distances.append((distance, item))
    distances.sort(key=lambda x: x[0])
    nearest_node = distances[0][1]
    print(f"\nNearest node to the query is Node ID: {nearest_node['node_id']} with content: '{nearest_node['content']}'")
    return nearest_node

def get_k_nearest_neighbors(current_node: Dict[str, any], embedded_data: List[Dict[str, any]], k: int) -> List[Dict[str, any]]:
    current_embedding = current_node['embedding']
    distances = []
    for item in embedded_data:
        distance = cosine(current_embedding, item['embedding'])
        distances.append((distance, item))
    distances.sort(key=lambda x: x[0])
    k_neighbors = [item for _, item in distances[:k]]
    print(f"\nK={k} nearest neighbors to Node ID: {current_node['node_id']}")
    for neighbor in k_neighbors:
        print(f"- Node ID: {neighbor['node_id']} | Content: '{neighbor['content']}'")
    return k_neighbors

def select_next_node_with_llm(current_context: str, possible_next_nodes: List[Dict[str, any]]) -> Optional[Dict[str, any]]:
    if not possible_next_nodes:
        print("No possible next nodes to select from.")
        return None

    # Prepare the messages for the Chat Completion API
    prompt = f"You are given the current context of a process:\n\n\"{current_context}\"\n\nPossible next steps are:\n"
    for idx, node in enumerate(possible_next_nodes):
        prompt += f"{idx + 1}. {node['content']}\n"
    prompt += "\nBased on the context, select the most appropriate next step from the list and provide only the number."

    print("\nPrompt to LLM:")
    print(prompt)

    # Call the OpenAI ChatCompletion API
    try:
        response = client.chat.completions.create(
            model="gpt-4",  # Specify your model (e.g., gpt-4, gpt-3.5-turbo, etc.)
            messages=[
                {"role": "system", "content": "You are an assistant that selects the next step in a process."},
                {"role": "user", "content": prompt}
            ],
            max_tokens=5,
            temperature=0
        )

        selection = response.data.choices[0].message.content.strip()
        print(f"\nLLM response: '{selection}'")

        # Extract the selected index
        selected_idx = int(selection) - 1
        if 0 <= selected_idx < len(possible_next_nodes):
            selected_node = possible_next_nodes[selected_idx]
            print(f"Selected next node: Node ID: {selected_node['node_id']} | Content: '{selected_node['content']}'")
            return selected_node
        else:
            print("LLM selected an invalid option.")
            return None
    except Exception as e:
        print(f"Error during LLM call: {e}")
        return None

def generate_full_path(query_content: str, embedded_data: List[Dict[str, any]], k: int) -> List[str]:
    print(f"\nGenerating embedding for query: '{query_content}'")
    query_embedding = generate_embedding(query_content)

    # Find the node closest to the query
    current_node = find_nearest_node(query_embedding, embedded_data)
    path = [current_node['node_id']]
    visited = set(path)
    accumulated_context = query_content + " " + current_node['content']

    while True:
        # Get k nearest neighbors of the current node
        k_neighbors = get_k_nearest_neighbors(current_node, embedded_data, k)

        # Collect possible next nodes from the k nearest neighbors
        possible_next_nodes = []
        next_node_ids = set()
        for neighbor in k_neighbors:
            for next_node_id in neighbor['next_nodes']:
                if next_node_id not in next_node_ids:
                    next_node = next((item for item in embedded_data if item['node_id'] == next_node_id), None)
                    if next_node:
                        possible_next_nodes.append(next_node)
                        next_node_ids.add(next_node_id)

        # Use LLM to select the next node
        next_node = select_next_node_with_llm(accumulated_context, possible_next_nodes)

        if not next_node or next_node['node_id'] in visited:
            print(f"\nStopping path generation. Next node: '{next_node['node_id'] if next_node else None}' | Visited: {visited}")
            break  # No more nodes to visit or loop detected

        path.append(next_node['node_id'])
        visited.add(next_node['node_id'])
        current_node = next_node

        # Update accumulated context
        accumulated_context += " " + current_node['content']

    return path

def node_id_to_content(node_id: str, embedded_data: List[Dict[str, any]]) -> str:
    node = next((item for item in embedded_data if item['node_id'] == node_id), None)
    return node['content'] if node else ""

# Example usage
if __name__ == "__main__":
    # Your input data
    sequences = [
        [
            "Open AWS Console",
            "Enter username",
            "Enter password",
            "Click Login Button",
            "Navigate to Services",
            "Select AWS Backup",
            "Click Create Backup Plan",
            "Enter Plan Name",
            "Define Backup Rules",
            "Click Create Plan"
        ],
        [
            "Open AWS Console",
            "Enter Login Information",
            "Select Services",
            "Choose Systems Manager",
            "Click Automation",
            "Create New Automation",
            "Select Document Type",
            "Configure Execution Parameters",
            "Click Execute"
        ],
        [
            "Go to AWS Login Page",
            "Enter username",
            "Enter password",
            "Click Login Button",
            "Navigate to Services",
            "Select ElasticSearch",
            "Click Create Domain",
            "Enter Domain Name",
            "Configure Settings",
            "Click Create"
        ],
        [
            "Open AWS Console",
            "Enter username",
            "Enter password",
            "Click Login Button",
            "Navigate to Services",
            "Select S3",
            "Click Create Bucket",
            "Enter Bucket Name",
            "Configure Bucket Settings",
            "Click Create Bucket"
        ],
    ]

    # Extract nodes and edges
    nodes = extract_nodes_and_edges(sequences)

    # Generate embeddings with metadata
    embedded_data = create_embeddings_with_metadata(nodes)

    # Query input
    query_content = "Create AWS bucket"
    k = 3  # Number of nearest neighbors to consider

    # Generate full path based on the query
    path_node_ids = generate_full_path(query_content, embedded_data, k)

    # Convert node IDs back to content for readability
    path_contents = [node_id_to_content(node_id, embedded_data) for node_id in path_node_ids]

    print("\nGenerated Path:")
    for step in path_contents:
        print(f"- {step}")
# Out:
# Extracting nodes and edges from sequences...
# Processing sequence: ['Open AWS Console', 'Enter username', 'Enter password', 'Click Login Button', 'Navigate to Services', 'Select AWS Backup', 'Click Create Backup Plan', 'Enter Plan Name', 'Define Backup Rules', 'Click Create Plan']
# Created node: node_1 with content: 'Open AWS Console'
# Created node: node_2 with content: 'Enter username'
# Added edge from 'node_1' to 'node_2'
# Created node: node_3 with content: 'Enter password'
# Added edge from 'node_2' to 'node_3'
# Created node: node_4 with content: 'Click Login Button'
# Added edge from 'node_3' to 'node_4'
# Created node: node_5 with content: 'Navigate to Services'
# Added edge from 'node_4' to 'node_5'
# Created node: node_6 with content: 'Select AWS Backup'
# Added edge from 'node_5' to 'node_6'
# Created node: node_7 with content: 'Click Create Backup Plan'
# Added edge from 'node_6' to 'node_7'
# Created node: node_8 with content: 'Enter Plan Name'
# Added edge from 'node_7' to 'node_8'
# Created node: node_9 with content: 'Define Backup Rules'
# Added edge from 'node_8' to 'node_9'
# Created node: node_10 with content: 'Click Create Plan'
# Added edge from 'node_9' to 'node_10'
# Processing sequence: ['Open AWS Console', 'Enter Login Information', 'Select Services', 'Choose Systems Manager', 'Click Automation', 'Create New Automation', 'Select Document Type', 'Configure Execution Parameters', 'Click Execute']
# Created node: node_11 with content: 'Enter Login Information'
# Added edge from 'node_1' to 'node_11'
# Created node: node_12 with content: 'Select Services'
# Added edge from 'node_11' to 'node_12'
# Created node: node_13 with content: 'Choose Systems Manager'
# Added edge from 'node_12' to 'node_13'
# Created node: node_14 with content: 'Click Automation'
# Added edge from 'node_13' to 'node_14'
# Created node: node_15 with content: 'Create New Automation'
# Added edge from 'node_14' to 'node_15'
# Created node: node_16 with content: 'Select Document Type'
# Added edge from 'node_15' to 'node_16'
# Created node: node_17 with content: 'Configure Execution Parameters'
# Added edge from 'node_16' to 'node_17'
# Created node: node_18 with content: 'Click Execute'
# Added edge from 'node_17' to 'node_18'
# Processing sequence: ['Go to AWS Login Page', 'Enter username', 'Enter password', 'Click Login Button', 'Navigate to Services', 'Select ElasticSearch', 'Click Create Domain', 'Enter Domain Name', 'Configure Settings', 'Click Create']
# Created node: node_19 with content: 'Go to AWS Login Page'
# Added edge from 'node_19' to 'node_2'
# Added edge from 'node_2' to 'node_3'
# Added edge from 'node_3' to 'node_4'
# Added edge from 'node_4' to 'node_5'
# Created node: node_20 with content: 'Select ElasticSearch'
# Added edge from 'node_5' to 'node_20'
# Created node: node_21 with content: 'Click Create Domain'
# Added edge from 'node_20' to 'node_21'
# Created node: node_22 with content: 'Enter Domain Name'
# Added edge from 'node_21' to 'node_22'
# Created node: node_23 with content: 'Configure Settings'
# Added edge from 'node_22' to 'node_23'
# Created node: node_24 with content: 'Click Create'
# Added edge from 'node_23' to 'node_24'
# Processing sequence: ['Open AWS Console', 'Enter username', 'Enter password', 'Click Login Button', 'Navigate to Services', 'Select S3', 'Click Create Bucket', 'Enter Bucket Name', 'Configure Bucket Settings', 'Click Create Bucket']
# Added edge from 'node_1' to 'node_2'
# Added edge from 'node_2' to 'node_3'
# Added edge from 'node_3' to 'node_4'
# Added edge from 'node_4' to 'node_5'
# Created node: node_25 with content: 'Select S3'
# Added edge from 'node_5' to 'node_25'
# Created node: node_26 with content: 'Click Create Bucket'
# Added edge from 'node_25' to 'node_26'
# Created node: node_27 with content: 'Enter Bucket Name'
# Added edge from 'node_26' to 'node_27'
# Created node: node_28 with content: 'Configure Bucket Settings'
# Added edge from 'node_27' to 'node_28'
# Added edge from 'node_28' to 'node_26'
#
# Generating embeddings for each node...
# Node ID: node_1
# Content: 'Open AWS Console'
# Next Nodes: ['node_11', 'node_2']
#
# Node ID: node_2
# Content: 'Enter username'
# Next Nodes: ['node_3']
#
# Node ID: node_3
# Content: 'Enter password'
# Next Nodes: ['node_4']
#
# Node ID: node_4
# Content: 'Click Login Button'
# Next Nodes: ['node_5']
#
# Node ID: node_5
# Content: 'Navigate to Services'
# Next Nodes: ['node_25', 'node_6', 'node_20']
#
# Node ID: node_6
# Content: 'Select AWS Backup'
# Next Nodes: ['node_7']
#
# Node ID: node_7
# Content: 'Click Create Backup Plan'
# Next Nodes: ['node_8']
#
# Node ID: node_8
# Content: 'Enter Plan Name'
# Next Nodes: ['node_9']
#
# Node ID: node_9
# Content: 'Define Backup Rules'
# Next Nodes: ['node_10']
#
# Node ID: node_10
# Content: 'Click Create Plan'
# Next Nodes: []
#
# Node ID: node_11
# Content: 'Enter Login Information'
# Next Nodes: ['node_12']
#
# Node ID: node_12
# Content: 'Select Services'
# Next Nodes: ['node_13']
#
# Node ID: node_13
# Content: 'Choose Systems Manager'
# Next Nodes: ['node_14']
#
# Node ID: node_14
# Content: 'Click Automation'
# Next Nodes: ['node_15']
#
# Node ID: node_15
# Content: 'Create New Automation'
# Next Nodes: ['node_16']
#
# Node ID: node_16
# Content: 'Select Document Type'
# Next Nodes: ['node_17']
#
# Node ID: node_17
# Content: 'Configure Execution Parameters'
# Next Nodes: ['node_18']
#
# Node ID: node_18
# Content: 'Click Execute'
# Next Nodes: []
#
# Node ID: node_19
# Content: 'Go to AWS Login Page'
# Next Nodes: ['node_2']
#
# Node ID: node_20
# Content: 'Select ElasticSearch'
# Next Nodes: ['node_21']
#
# Node ID: node_21
# Content: 'Click Create Domain'
# Next Nodes: ['node_22']
#
# Node ID: node_22
# Content: 'Enter Domain Name'
# Next Nodes: ['node_23']
#
# Node ID: node_23
# Content: 'Configure Settings'
# Next Nodes: ['node_24']
#
# Node ID: node_24
# Content: 'Click Create'
# Next Nodes: []
#
# Node ID: node_25
# Content: 'Select S3'
# Next Nodes: ['node_26']
#
# Node ID: node_26
# Content: 'Click Create Bucket'
# Next Nodes: ['node_27']
#
# Node ID: node_27
# Content: 'Enter Bucket Name'
# Next Nodes: ['node_28']
#
# Node ID: node_28
# Content: 'Configure Bucket Settings'
# Next Nodes: ['node_26']
#
#
# Generating embedding for query: 'Create AWS bucket'
#
# Nearest node to the query is Node ID: node_26 with content: 'Click Create Bucket'
#
# K=3 nearest neighbors to Node ID: node_26
# - Node ID: node_26 | Content: 'Click Create Bucket'
# - Node ID: node_27 | Content: 'Enter Bucket Name'
# - Node ID: node_28 | Content: 'Configure Bucket Settings'
#
# Prompt to LLM:
# You are given the current context of a process:
#
# "Create AWS bucket Click Create Bucket"
#
# Possible next steps are:
# 1. Enter Bucket Name
# 2. Configure Bucket Settings
# 3. Click Create Bucket
#
# Based on the context, select the most appropriate next step from the list and provide only the number.
# Error during LLM call: 'ChatCompletion' object is not subscriptable
#
# Stopping path generation. Next node: 'None' | Visited: {'node_26'}
#
# Generated Path:
# - Click Create Bucket
